# %%
#Importar las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar desde un archivo .csv sin indice
dataframe = pd.read_excel('Gastos y costos 20-23 (1).xlsx', sheet_name= '2022')
dataframe
# Out:
#      CALOR Y CONTROL S.A DE C.V  Unnamed: 1  \
# 0              DEDUCCIONES 2022         NaN
# 1                           NaN         NaN
# 2                         Fecha       Folio
# 3           2022-01-01 00:00:00      280108
# 4           2022-01-01 00:00:00      280109
# ...                         ...         ...
# 2575        2022-12-01 00:00:00      863376
# 2576        2022-12-01 00:00:00  1092957089
# 2577        2022-12-01 00:00:00           4
# 2578        2022-12-01 00:00:00          16
# 2579        2022-12-01 00:00:00          17
#
#                                 Unnamed: 2    Unnamed: 3  \
# 0                                      NaN           NaN
# 1                                      NaN           NaN
# 2                                     UUID           RFC
# 3     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E  BLE1512082R9
# 4     7E00E776-A839-4D57-B291-411109164B2F  BLE1512082R9
# ...                                    ...           ...
# ...

# %%
#Eliminar primera fila o filas inecesarias
dataframe= pd.read_excel('Gastos y costos 20-23 (1).xlsx', sheet_name= '2022', skiprows=3)
dataframe
# Out:
#           Fecha         Folio                                  UUID  \
# 0    2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1    2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2    2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3    2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4    2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...         ...           ...                                   ...
# 2572 2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573 2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574 2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575 2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576 2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        2577 non-null   datetime64[ns]
#  1   Folio        2475 non-null   object
#  2   UUID         2577 non-null   object
#  3   RFC          2577 non-null   object
#  4   Proveedor    2577 non-null   object
#  5   TIPO GASTO   2577 non-null   object
#  6   Descripción  2577 non-null   object
#  7   MP           2024 non-null   object
#  8   TC           1941 non-null   float64
#  9   Importe      2577 non-null   float64
#  10  IVA          2577 non-null   float64
#  11  RET ISR      2577 non-null   float64
#  12  RET IVA      2577 non-null   float64
#  13  Otros        0 non-null      float64
#  14  TOTAL MX     2577 non-null   float64
#  15  TOTAL SAT    2577 non-null   float64
#  16  Tipo         2577 non-null   object
#  17  Status       2577 non-null   object
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=dataframe.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(4669)

# %%
#Identificar valores nulos por columna
valores_nulos=dataframe.isnull().sum()
valores_nulos
# Out:
# Fecha             0
# Folio           102
# UUID              0
# RFC               0
# Proveedor         0
# TIPO GASTO        0
# Descripción       0
# MP              553
# TC              636
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# Otros          2577
# TOTAL MX          0
# TOTAL SAT         0
# Tipo              0
# Status            0
# Poliza          801
# dtype: int64

# %%
#Realizamos una copia  del dataframe
dataframe1=dataframe.copy()

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of           Fecha         Folio                                  UUID  \
# 0    2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1    2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2    2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3    2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4    2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...         ...           ...                                   ...
# 2572 2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573 2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574 2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575 2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576 2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# ...

# %%
#primer metodo de sustitucion de valores nulos
#sustituir valores nulos con promedio o media
dataframe1["TC"]=dataframe1["TC"].fillna(round(dataframe["TC"].mean(),1))

# %%
#segundo metodo de sustitucion de valores nulos
#Sustituir valores nulos por un string en concreto
dataframe1["MP"]=dataframe1["MP"].fillna("PAGADO")

# %%
#Corroboramos valores nulos
valores_nulos=dataframe1.isnull().sum()
valores_nulos
# Out:
# Fecha             0
# Folio           102
# UUID              0
# RFC               0
# Proveedor         0
# TIPO GASTO        0
# Descripción       0
# MP                0
# TC                0
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# Otros          2577
# TOTAL MX          0
# TOTAL SAT         0
# Tipo              0
# Status            0
# Poliza          801
# dtype: int64

# %%
#segundo metodo de sustitucion de valores nulos
#Sustituir valores nulos por un string en concreto
dataframe1["Poliza"]=dataframe1["Poliza"].fillna("Sin Poliza")

# %%
#Corroboramos valores nulos
valores_nulos=dataframe1.isnull().sum()
valores_nulos
# Out:
# Fecha             0
# Folio           102
# UUID              0
# RFC               0
# Proveedor         0
# TIPO GASTO        0
# Descripción       0
# MP                0
# TC                0
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# Otros          2577
# TOTAL MX          0
# TOTAL SAT         0
# Tipo              0
# Status            0
# Poliza            0
# dtype: int64

# %%
#Tercer metodo de sustitucion de valores nulos
#Sustituir valores nulos por un valor númerico en concreto 
dataframe1["Otros"]= dataframe1["Otros"].fillna(0)
dataframe1
# Out:
#           Fecha         Folio                                  UUID  \
# 0    2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1    2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2    2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3    2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4    2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...         ...           ...                                   ...
# 2572 2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573 2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574 2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575 2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576 2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ...

# %%
#Corroboramos valores nulos
valores_nulos=dataframe1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio          102
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       0
# Descripción      0
# MP               0
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros            0
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza           0
# dtype: int64

# %%
#Tercer metodo de sustitucion de valores nulos
#Sustituir valores nulos por un valor númerico en concreto 
dataframe1["Folio"]= dataframe1["Folio"].fillna(000000)
dataframe1
# Out:
#           Fecha         Folio                                  UUID  \
# 0    2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1    2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2    2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3    2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4    2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...         ...           ...                                   ...
# 2572 2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573 2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574 2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575 2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576 2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ...

# %%
#Corroboramos valores nulos
valores_nulos=dataframe1.isnull().sum()
valores_nulos
# Out:
# Fecha          0
# Folio          0
# UUID           0
# RFC            0
# Proveedor      0
# TIPO GASTO     0
# Descripción    0
# MP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# Otros          0
# TOTAL MX       0
# TOTAL SAT      0
# Tipo           0
# Status         0
# Poliza         0
# dtype: int64

# %%
#Convertir DataFrame a CSV
dataframe1.to_csv("Gastos y costos 2022_sin_nulos.csv")
